# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# ?np.loadtxt
# check the arguments: delimiter, dtype, comments, skiprows

# %%
# please, paste your own data path
mtx_filename = 'test_armatus_1/simHiC_countMatrix_1227180_10-26_18h34m41s.txt'
mtx = np.loadtxt(mtx_filename)

# %%
tads_filename = 'test_armatus_1/test1.consensus.del.txt' # ... 
tads = np.loadtxt(tads_filename, delimiter='\t') # or delimiter='\s'

# %%
# ?sns.heatmap
# check the arguments: cmap, vmax, vmin, center, cbar

# %%
mtx.shape[1]
# Out:
# 4519

# %%
#basic usage
bgn = 0
end = 100
sns.heatmap(mtx[bgn:end, bgn:end])

# %%
# let's make it nice!

# global settings of the plot
bgn = 0
end = 500
tads_color = 'blue'

# plot tuning
plt.figure(figsize=(24,20))
sns.heatmap(mtx[bgn:end, bgn:end], cmap='Reds')
plt.xticks([])
plt.yticks([])

# tads drawing, please, check +-1 errors on real data!
for i in tads:
    tad_bgn = i[0] - bgn # guess why we need this? 
    tad_end = i[1] - bgn + 1
    plt.plot([tad_bgn, tad_end], [tad_bgn, tad_bgn], color=tads_color)
    plt.plot([tad_end, tad_end], [tad_bgn, tad_end], color=tads_color)
